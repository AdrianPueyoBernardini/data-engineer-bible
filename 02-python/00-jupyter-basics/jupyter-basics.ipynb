# %% [markdown]
# # **JUPYTER NOTEBOOKS**

# %% [markdown]
# Esto es un documento de Jupiter Notebook, desde aquí podemos lanzar ejecutables por celdas sin tener que ejecutar el script completo.

# %%
"Esto es codigo Python"

# %%
2+2*4

# %% [markdown]
# Al ejecutar el código, exclusivamente recibiremos la última linea, para poder ver por consola varias lineas en una misma celda, podemos usar: print()

# %%
print(4+4)
print("Esto será multilinea")

# %% [markdown]
# Para agregar comentarios sin salida "#"

# %%
#Esto es un comentario de python
