# %% [markdown]
# ## **Basicos: Jupyter**

# %% [markdown]
#  Ejecutable de linea simple

# %%
1+1 #Comentarios

# %% [markdown]
# Ejecutar comandos multilinea

# %%
print("Comando 1")
print("Comando 2")
