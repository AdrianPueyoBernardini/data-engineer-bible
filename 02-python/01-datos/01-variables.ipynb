# %% [markdown]
# # **Variables**

# %%
# String 
empleado = "adrian"

#int
edad = 26

#float
salario = 30000

incentivo = 0.10

print(empleado)
print(edad)
print(salario)
# Out:
# adrian
# 26
# 30000

# %% [markdown]
# Podemos almacenar viariables y ejecutarlas en consecuencia

# %%
salario_final = salario + (salario*incentivo)

# %%
salario_final
# Out:
# 33000.0
