# %% [markdown]
# ## **Numbers**

# %% [markdown]
# >**Basics**

# %%
#Integers
mi_integer = 3;
print(mi_integer);

#Floats o decimales
mi_float = 0.4;
print(mi_float);

# %% [markdown]
# *Lo interesante de jupyter es que estas variables quedan almacenadas exclusivamente si se ejecuta el bloque de codigo anterior.*

# %%
mi_float

# %% [markdown]
# >**Saber el tipo de dato: TYPE()**

# %%
nombre = "pepe"
print(type(nombre))
# Out:
# <class 'str'>
