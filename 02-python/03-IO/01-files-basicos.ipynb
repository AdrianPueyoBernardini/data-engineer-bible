# %% [markdown]
# ## **IO**

# %% [markdown]
# >**Basics**

# %% [markdown]
# >No puede haber un comentario o %%writefile nos dará error en la ejecución
# >Si ejecutamos la celda dos veces, nos sobrescribirá el archivo

# %%
# %%writefile mi_archivo.txt
# Aquí podemos poner las lineas que queremos
# tantas como sean
# se grabarán en el txt

# %%
pwd
# Out:
# 'c:\\Users\\apueyobernardini\\OneDrive - Deloitte (O365D)\\Documents\\Adrian\\data-engineer-bible\\02-python\\03-IO'
