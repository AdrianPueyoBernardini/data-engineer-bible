# %% [markdown]
# ## **Librerias datos: Numpy**

# %% [markdown]
# >**Basics**

# %% [markdown]
# La libreria numpy nos permite crear y modificar matrices y hacer operaciones sobre ellas.
# Para empezar a utilizar Numpy tenemos que importar la librería, pero antes, tenemos que isntalar algunas librerías que vamos a utilizar

# %%
# %pip install numpy pandas scikit-learn matplotlib

# %% [markdown]
# Y ahora si:

# %%
import numpy as np
