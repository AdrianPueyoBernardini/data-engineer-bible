# %% [markdown]
# ## **Pandas: Basics #2: Creación de dataframes propios**

# %% [markdown]
# >**1. Instalación de pandas e importación del módulo**

# %%
# %pip install pandas

# %%
import pandas as pd
import io

# %% [markdown]
# >**2. Creamos una string que formará nuestro dataframe**

# %%
str_dataset = '''valor1,valor2
10,300
7,240
11,315
8, 295
15,402
'''

# %% [markdown]
# >**3. io.StringIO()**

# %%
#Con io.StringIO convertimos y leemos
str_dataframe = pd.read_csv(io.StringIO(str_dataset))
str_dataframe.head(5)
# Out:
#    valor1  valor2
# 0      10     300
# 1       7     240
# 2      11     315
# 3       8     295
# 4      15     402
