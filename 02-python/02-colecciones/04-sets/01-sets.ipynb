# %% [markdown]
# ## **Sets**

# %% [markdown]
# >**Basics**

# %%
#Los Sets son algo distintos, no permiten valores DUPLICADOS
my_set = set()
my_set.add(1)
print(my_set)

my_set.add(2)
print(my_set)

# %% [markdown]
# >**Basics 2**

# %%
#Podemos ver un ejemplo interesante
my_set_2 = set('adrian')
print(my_set_2) #No repite la "a" ya que aparece dos veces
# Out:
# {'n', 'r', 'a', 'd', 'i'}
